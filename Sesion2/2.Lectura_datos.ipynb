# %%
# %pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from sqlalchemy) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sqlalchemy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in /usr/local/python/3.10.13/lib/python3.10/site-packages (5.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in /usr/local/python/3.10.13/lib/python3.10/site-packages (4.7.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pymongo[srv]) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install mysqlclient
# Out:
# Requirement already satisfied: mysqlclient in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd
from pymongo import MongoClient

# %%
## Conectar a mysql Se pasa ese link ya que estamos utilizando el codespace es el mismo root para todos 
engine = db.create_engine("mysql://root:root@172.16.5.4:3310/retail_db") 
conn = engine.connect()

# %%
#Jalamos datos de la base datos retail_db
df_customers = pd.read_sql_query("SELECT * FROM customers", con=conn)
df_customers.tail()
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 12430         XXXXXXXXX           1221 Cinder Pines       Kaneohe
# 12431         XXXXXXXXX  1525 Jagged Barn Highlands        Caguas
# 12432         XXXXXXXXX    5459 Noble Brook Landing     Levittown
# 12433         XXXXXXXXX        9720 Colonial Parade        Caguas
# 12434         XXXXXXXXX            5736 Honey Downs   Summerville
#
#       customer_state customer_zipcode
# 12430             HI            96744
# 12431             PR            00725
# 12432             NY            11756
# 12433             PR            00725
# 12434             SC            29483

# %%
#Conexion a mongodb
 
CONNECTION_STRING = "mongodb+srv://andreigaled3:txmnM3oUgWMsnxFy@cluster0.qdxwmr6.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(CONNECTION_STRING)

# %%
#Trabajremos sobre esta base de datos
dbname = client["retail_db"]

# %%
#Mongo DB trabaja con conexiones,Nos permite llevar la informacion de nuestro dataframe a la base de dato retail.
#tenemos que tranformas nuestro DT en un diccionario 
df = df_customers.copy()
df_to_dict = df.to_dict("records")
dbname["customers"].insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('667c6ac72b583bdbdd30dd11'), ObjectId('667c6ac72b583bdbdd30dd12'), ObjectId('667c6ac72b583bdbdd30dd13'), ObjectId('667c6ac72b583bdbdd30dd14'), ObjectId('667c6ac72b583bdbdd30dd15'), ObjectId('667c6ac72b583bdbdd30dd16'), ObjectId('667c6ac72b583bdbdd30dd17'), ObjectId('667c6ac72b583bdbdd30dd18'), ObjectId('667c6ac72b583bdbdd30dd19'), ObjectId('667c6ac72b583bdbdd30dd1a'), ObjectId('667c6ac72b583bdbdd30dd1b'), ObjectId('667c6ac72b583bdbdd30dd1c'), ObjectId('667c6ac72b583bdbdd30dd1d'), ObjectId('667c6ac72b583bdbdd30dd1e'), ObjectId('667c6ac72b583bdbdd30dd1f'), ObjectId('667c6ac72b583bdbdd30dd20'), ObjectId('667c6ac72b583bdbdd30dd21'), ObjectId('667c6ac72b583bdbdd30dd22'), ObjectId('667c6ac
ObjectId('667c6ac72b583bdbdd30dd64'), ObjectId('667c6ac72b583bdbdd30dd65'), ObjectId('667c6ac72b583bdbdd30dd66'), ObjectId('667c6ac72b583bdbdd30dd67'), ObjectId('667c6ac72b583bdbdd30dd68'), ObjectId('667c6ac72b583bdbdd30dd69'), ObjectId('667c6ac72b583bdbdd30dd6a'), ObjectId('667c6ac72b583bdbdd30dd6b'), ObjectId('667c6ac72b583bdbdd30dd6c'), ObjectId('667c6ac72b583bdbdd30dd6d'), ObjectId('667c6ac72b583bdbdd30dd6e'), ObjectId('667c6ac72b583bdbdd30dd6f'), ObjectId('667c6ac72b583bdbdd30dd70'), ObjectId('667c6ac72b583bdbdd30dd71'), ObjectId('667c6ac72b583bdbdd30dd72'), ObjectId('667c6ac72b583bdbdd30dd73'), ObjectId('667c6ac72b583bdbdd30dd74'), ObjectId('667c6ac72b583bdbdd30dd75'), ObjectId('667c6ac72b583bdbdd30dd76'), ObjectId('667c6ac72b583bdbdd30dd77'), ObjectId('667c6ac72b583bdbdd30dd78'), ObjectId('667c6ac72b583bdbdd30 ...

# %%
#traemos data de mongo a git 
collection_customers = dbname['customers'] 

customers = collection_customers.find({})

customers

# %%
#creamos un data frame de los datos que hemos traido
df_customers_mongo = pd.DataFrame(customers)

df_customers_mongo
# Out:
#                             _id  customer_id customer_fname customer_lname  \
# 0      667c6a980a9ff9afc51c4955            1        Richard      Hernandez
# 1      667c6a980a9ff9afc51c4956            2           Mary        Barrett
# 2      667c6a980a9ff9afc51c4957            3            Ann          Smith
# 3      667c6a980a9ff9afc51c4958            4           Mary          Jones
# 4      667c6a980a9ff9afc51c4959            5         Robert         Hudson
# ...                         ...          ...            ...            ...
# 24865  667c6ac72b583bdbdd310d9f        12431           Mary           Rios
# 24866  667c6ac72b583bdbdd310da0        12432         Angela          Smith
# 24867  667c6ac72b583bdbdd310da1        12433       Benjamin         Garcia
# 24868  667c6ac72b583bdbdd310da2        12434           Mary          Mills
# 24869  667c6ac72b583bdbdd310da3        12435          Laura         Horton
#
#       customer_email customer_password             customer_street  \
# 0          XXXXXXXXX         XXXXXXXXX          6303 Heather Plaza
# 1          XXXXXXXXX         XXXXXXXXX     9526 Noble Embers Ridge
# 2          XXXXXXXXX         XXXXXXXXX      3422 Blue Pioneer Bend
# 3          XXXXXXXXX         XXXXXXXXX          8324 Little Common
# 4          XXXXXXXXX         XXXXXXXXX      10 Crystal River Mall
# ...              ...               ...                         ...
# 24865      XXXXXXXXX         XXXXXXXXX           1221 Cinder Pines
# 24866      XXXXXXXXX         XXXXXXXXX  1525 Jagged Barn Highlands
# 24867      XXXXXXXXX         XXXXXXXXX    5459 Noble Brook Landing
# 24868      XXXXXXXXX         XXXXXXXXX        9720 Colonial Parade
# 24869      XXXXXXXXX         XXXXXXXXX            5736 Honey Downs
#
#       customer_city customer_state customer_zipcode
# 0       Brownsville             TX            78521
# 1         Littleton             CO            80126
# 2            Caguas             PR            00725
# 3        San Marcos             CA            92069
# 4            Caguas             PR            00725
# ...             ...            ...              ...
# 24865       Kaneohe             HI            96744
# 24866        Caguas             PR            00725
# 24867     Levittown             NY            11756
# 24868        Caguas             PR            00725
# 24869   Summerville             SC            29483
#
# [24870 rows x 10 columns]
